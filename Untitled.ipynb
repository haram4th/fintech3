# %%
import pandas as pd

# %%
data = pd.read_csv("./06machine_learning/data/toss_reviews.csv")
data
# Out:
#        Unnamed: 0       사용자  별점  \
# 0               0  Won Choi   5
# 1               1       최유연   5
# 2               2   EXPRESS   5
# 3               3      JS P   5
# 4               4  AndPeter   5
# ...           ...       ...  ..
# 57223       57223        김민   5
# 57224       57224       최고운   5
# 57225       57225        블리   5
# 57226       57226       조명현   5
# 57227       57227       이예진   5
#
#                                                       리뷰             날짜  \
# 0      토스 많이 이용하는데 나쁘지 않음. 하지만 연말정산 잘 알지 않으면 돌려받기는 사용...  2024년 11월 19일
# 1      증권부분이 너무 빈약해요. 이평선, 분봉, 틱봉 자유롭게 수치를 설정할 수 있었음 ...   2025년 1월 18일
# 2      주식 UI에서 홈과 관심 종목을 나눈 것도 불편한데 이번 자주 사용하는 계좌 업데이...   2025년 2월 25일
# 3      언제 한 번 대대적으로 앱 퍼포먼스 최적화를 했으면 좋겠습니다. 예전엔 이러지 않았...   2025년 2월 28일
# 4      앱 최적화 좀 해주세요! 무슨 메모리를 1GB나 잡아먹고 패킷전송이 하루에 80만건...    2025년 3월 1일
# ...                                                  ...            ...
# ...

# %%
data.duplicated().count()
# Out:
# np.int64(57228)

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 사용자, 별점, 리뷰, 날짜, 개발자 응답]
# Index: []
