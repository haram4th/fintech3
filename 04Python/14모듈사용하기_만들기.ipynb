# %% [markdown]
# # 모듈
# * 누군가가 미리 사용하기 편하게 만들어 놓은 함수, 클래스
# * import 명령을 이용해서 프로그램 가장 위에서 모듈을 불러와 사용할 수 있음
# * 모듈에 너무 많은 기능이 있는 경우 from 모듈명 import 함수/클래스 형식으로 일부 기능만 불러올 수도 있음
# * 모듈은 사용자가 직접 만들 수도 있음
# * 사용자 모듈을 불러올 때는 실행하는 파일과 같은 위치에 있어야 함

# %% [markdown]
# # datatime 모듈 사용하기

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 10, 13, 9, 13, 11, 657936)

# %%
now = datetime.now()
print(now)
# Out:
# 2025-10-13 09:13:40.592311

# %%
print(type(now))
# Out:
# <class 'datetime.datetime'>

# %%
now.year
# Out:
# 2025

# %%
now.month
# Out:
# 10

# %%
now.day
# Out:
# 13

# %% [markdown]
# "2025-10-13"

# %%
print(f"{now.year}-{now.month:02d}-{now.day:02d}")
# Out:
# 2025-10-13

# %%
now.hour
# Out:
# 9

# %%
now.minute
# Out:
# 13

# %%
now.second
# Out:
# 40

# %% [markdown]
# 시간을 포멧에 맞춰 출력하기 strftime(%Y, %m )

# %%
now.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2025.10.13 09:13:40'

# %%
now.strftime("%y.%m.%d %H:%M:%S")
# Out:
# '25.10.13 09:13:40'

# %% [markdown]
# # OS모듈
# * cmd명령어를 python 코드에서 실행하는 모듈

# %%
import os

# %%
# 내가 사용하는 컴퓨터의 기본정보 출력하기
print("현재 운영체제: ", os.name)
print("현재 사용하는 폴더: ", os.getcwd())
print("현재 폴더 내부의 파일 리스트: ", os.listdir())
# Out:
# 현재 운영체제:  nt
# 현재 사용하는 폴더:  c:\fintech3\04Python
# 현재 폴더 내부의 파일 리스트:  ['.ipynb_checkpoints', '01주피터노트북사용법.ipynb', '02파이썬 기초 문법.ipynb', '03변수_자료형_연산자.ipynb', '04문자열과_문자열함수_input.ipynb', '05리스트와 튜플 사용하기.ipynb', '06딕셔너리사용하기.ipynb', '07서식지정자와 문자열 포메팅.ipynb', '08조건문.ipynb', '09반복문_for_while.ipynb', '10리스트표현식_파일읽기쓰기_json자료정리.ipynb', '11JSON데이터 언패킹해서 CSV파일로 만들기.ipynb', '12함수만들기_예외처리.ipynb', '13클래스_객체지향형프로그래밍.ipynb', '14모듈사용하기_만들기.ipynb', 'ch10데이터 집계와 그룹연산.ipynb', 'data', 'Miniforge_주피터노트북 설치 및 설정.pdf', '절차적_함수형_객체지향형_프로그래밍.pdf', '호텔정보추출하기.txt']

# %%
# 현재 위치에서 폴더 만들기
os.mkdir("testdir")

# %%
# 현재 위치에서 폴더 삭제하기
os.rmdir("testdir")

# %%
# cmd 명령어 실행하기 실행완료 0, 실행실패 1
os.system("tree")
# Out:
# 0

# %%
# 파일을 생성하고 파일 이름 변경하기
with open("original.txt", "w") as file:
    file.write("안녕하세요")

# %%
os.rename("original.txt", "new_name.txt")

# %%
# 폴더가 있는지 확인하고 없으면 폴더 생성하기
if not os.path.exists("./testdir"):
    os.mkdir("testdir")
else:
    print("testdir이 이미 있습니다.")
# Out:
# testdir이 이미 있습니다.

# %%
# 환경변수에 변수와 값 추가하기/ 읽어오기, 현재파일이 실행되는 동안에만 저장됨
os.environ['key'] = "value"

# 등록된 환경변수 값 불러오기
print(os.environ.get('key'))
# Out:
# value

# %% [markdown]
# # 내가 만든 함수, 클래스 불러와서 사용하기

# %%
from mymodule import Cal, add

# %%
add(3,4)
# Out:
# 7

# %%
sam = Cal(3, 4)

# %%
sam.add()
# Out:
# 7

# %%
sam.sub()
# Out:
# -1
