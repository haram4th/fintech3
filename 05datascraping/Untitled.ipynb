# %%
import requests
import pandas as pd
from dotenv import load_dotenv
import os
import re
from datetime import datetime
load_dotenv(dotenv_path=".env")


def text_clean(text):
    # html 태그를 없애는 정규표현식
    result = re.sub(r"</?[^>]+>", "", text)
    # 한글, 영문, 숫자 외의 모든 문자 제거 후 공백으로 변환
    result = re.sub(r"[^가-힣a-zA-Z0-9]", " ", result)
    result = result.replace("  ", " ").replace("  ", " ").replace("  ", " ")
    return result


def naver_api(keyword):
    page_num = 1
    total_page = 1
    start_num = 1
    
    result = {}
    while page_num <= total_page:
        print(page_num, total_page, end="\r")
        user_id = os.getenv("Id")
        user_secret = os.getenv("Secret")
        url = f"https://openapi.naver.com/v1/search/news"
        payload = dict(query=keyword, display=100, start=start_num, sort="date")
        headers = {"X-Naver-Client-Id" : user_id, "X-Naver-Client-Secret" : user_secret}
        r = requests.get(url, params=payload, headers=headers)
        response = r.json()

        
        for item in response['items']:

            for key, value in item.items():
                if key in ['title', 'description']:
                    result.setdefault(key, []).append(text_clean(value))
                else:
                    result.setdefault(key, []).append(value)
        
        
        
        total_page = response['total'] // 100 + 1
        if total_page > 11:
            total_page = 11
        else:
            total_page = response['total'] // 100 + 1


        page_num += 1

        if start_num < 901:
            start_num += 100
        elif start_num > 900:
            start_num += 99

    print(result)

# %%
naver_api("핀테크")
# Out:
# {'title': ['트립비토즈 두바이 GITEX 2025서 iOL과 전략적 파트너십 체결', '올라핀테크 PG 핀트리니티에 전략적 지분 투자 신규 사업 확장', 'LS전선 AI 데이터센터 시장 본격 공략 DCWA 2025 서 핵심 솔루션 선보 ', ' 진단 금융지주 핀크 장일호 대표 체제 핀크 일부 서비스 철수 후 마 ', '아톤 메리츠증권에 안면인식 솔루션 공급', ' 오후 뉴스브리핑 바이낸스 고팍스 임원 변경 신청 수리 ', '아톤 메리츠증권에 화이트박스 암호화 기반 안면인식 솔루션 공급', '잉글랜드은행 스테이블코인 거래 한도 일시적 조치 선언 규제 완화 ', '경매투자도 이제 AI시대 땅집고옥션 땅집봇 토스 미니앱 론칭', '토큰증권 제도화 앞 영국 펀드 토큰화 프랑스 주식 토큰화 ', 'JHPLUS 온투업 신규 인허가 획득 금융시장 혁신 흐름에 합류', ' 스테이블코인 토스의 큰 전환점 슈퍼앱으로 승부 헤경이 만난 사 ', '비트코인 11만달러대로 하락 시장서 저가 매수세 유입 코인브리핑 ', ' 네이버 두나무 인수로 실적 개선 기대 DB증권 오늘 이 종목 ', '피규어 SEC 승인 디지털 국채 수이 블록체인 상륙', '아톤 안면인식 보안 솔루션 메리츠 증권에 공급', '사람인 한국경제인협회와 2025 상생협력 채용박람회 실시 ', ' quot 돌봄 인력 부족 해법 찾는다 quot 일본이 주목한 에이지테크 ', 'LS전선 AI 데이터센터 글로벌 시장 공략 강화', ' 금융권 CEO 연임 시험대 전북은행 백종일 3연임 도전 건전성 악화 ', '사람인 한국경제인협회 2025 상생협력 채용박람회 연다 삼성 S ', '아톤 메리츠증권에 화이트박스 암호화 기술 적용한 안면인식 솔루션 ', 'LS전선 글로벌 AI 데이터센