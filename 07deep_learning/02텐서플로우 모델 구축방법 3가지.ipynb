# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../06machine_learning/data/Titanic_train.csv")
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data = data[['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked']]
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0           0       3    male  22.0      1      0        S
# 1           1       1  female  38.0      1      0        C
# 2           1       3  female  26.0      0      0        S
# 3           1       1  female  35.0      1      0        S
# 4           0       3    male  35.0      0      0        S
# ..        ...     ...     ...   ...    ...    ...      ...
# 886         0       2    male  27.0      0      0        S
# 887         1       1  female  19.0      0      0        S
# 888         0       3  female   NaN      1      2        S
# 889         1       1    male  26.0      0      0        C
# 890         0       3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
data['family'] = data['SibSp'] + data['Parch']

# %%
data = data.drop(['SibSp', 'Parch'], axis=1)
data
# Out:
#      Survived  Pclass     Sex   Age Embarked  family
# 0           0       3    male  22.0        S       1
# 1           1       1  female  38.0        C       1
# 2           1       3  female  26.0        S       0
# 3           1       1  female  35.0        S       1
# 4           0       3    male  35.0        S       0
# ..        ...     ...     ...   ...      ...     ...
# 886         0       2    male  27.0        S       0
# 887         1       1  female  19.0        S       0
# 888         0       3  female   NaN        S       3
# 889         1       1    male  26.0        C       0
# 890         0       3    male  32.0        Q       0
#
# [891 rows x 6 columns]

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
data['Embarked'] = data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       891 non-null    float64
#  4   Embarked  891 non-null    object
#  5   family    891 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 41.9+ KB

# %%
X = data.drop('Survived', axis=1)
y = data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %% [markdown]
# # 딥러닝시에도 데이터의 스케일을 맞춰 주는것이 좋다.
# * StandardScaler, MinMaxScaler를 주로 사용, 이상값이 많을 경우 RobustScaler를 사용
# * 이진분류(0,1): MinMaxScaler
# * 연속값예측: StandardScaler

# %%
X_train
# Out:
#      Pclass     Sex        Age Embarked  family
# 748       1    male  19.000000        S       1
# 45        3    male  29.699118        S       0
# 28        3  female  29.699118        Q       0
# 633       1    male  29.699118        S       0
# 403       3    male  28.000000        S       1
# ..      ...     ...        ...      ...     ...
# 476       2    male  34.000000        S       1
# 190       2  female  32.000000        S       0
# 736       3  female  48.000000        S       4
# 462       1    male  47.000000        S       0
# 136       1  female  19.000000        S       2
#
# [623 rows x 5 columns]

# %%
cat_cols = X_train.select_dtypes(include='object').columns
num_cols = X_train.select_dtypes(exclude='object').columns
print(cat_cols)
print(num_cols)
# Out:
# Index(['Sex', 'Embarked'], dtype='object')
# Index(['Pclass', 'Age', 'family'], dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

# %%
ohe = OneHotEncoder(handle_unknown='ignore', drop='first', sparse_output=False)
ohe.fit(X_train[cat_cols])
ohe_X_train = ohe.transform(X_train[cat_cols])
ohe_X_test = ohe.transform(X_test[cat_cols])
ohe_X_train_df = pd.DataFrame(ohe_X_train, columns=ohe.get_feature_names_out(), index= X_train.index)
ohe_X_test_df = pd.DataFrame(ohe_X_test, columns=ohe.get_feature_names_out(), index= X_test.index)

# %%
ohe_X_train_df
# Out:
#      Sex_male  Embarked_Q  Embarked_S
# 748       1.0         0.0         1.0
# 45        1.0         0.0         1.0
# 28        0.0         1.0         0.0
# 633       1.0         0.0         1.0
# 403       1.0         0.0         1.0
# ..        ...         ...         ...
# 476       1.0         0.0         1.0
# 190       0.0         0.0         1.0
# 736       0.0         0.0         1.0
# 462       1.0         0.0         1.0
# 136       0.0         0.0         1.0
#
# [623 rows x 3 columns]

# %%
mms = MinMaxScaler()
mms.fit(X_train[num_cols])
mms_X_train = mms.transform(X_train[num_cols])
mms_X_test = mms.transform(X_test[num_cols])
mms_X_train_df = pd.DataFrame(mms_X_train, columns=X_train[num_cols].columns, index= X_train.index)
mms_X_test_df = pd.DataFrame(mms_X_test, columns=X_test[num_cols].columns, index= X_test.index)
mms_X_train_df
# Out:
#      Pclass       Age  family
# 748     0.0  0.233476     0.1
# 45      1.0  0.367921     0.0
# 28      1.0  0.367921     0.0
# 633     0.0  0.367921     0.0
# 403     1.0  0.346569     0.1
# ..      ...       ...     ...
# 476     0.5  0.421965     0.1
# 190     0.5  0.396833     0.0
# 736     1.0  0.597889     0.4
# 462     0.0  0.585323     0.0
# 136     0.0  0.233476     0.2
#
# [623 rows x 3 columns]

# %%
X_train_df = pd.concat([mms_X_train_df, ohe_X_train_df], axis=1)
X_test_df = pd.concat([mms_X_test_df, ohe_X_test_df], axis=1)

# %%
X_train_df
# Out:
#      Pclass       Age  family  Sex_male  Embarked_Q  Embarked_S
# 748     0.0  0.233476     0.1       1.0         0.0         1.0
# 45      1.0  0.367921     0.0       1.0         0.0         1.0
# 28      1.0  0.367921     0.0       0.0         1.0         0.0
# 633     0.0  0.367921     0.0       1.0         0.0         1.0
# 403     1.0  0.346569     0.1       1.0         0.0         1.0
# ..      ...       ...     ...       ...         ...         ...
# 476     0.5  0.421965     0.1       1.0         0.0         1.0
# 190     0.5  0.396833     0.0       0.0         0.0         1.0
# 736     1.0  0.597889     0.4       0.0         0.0         1.0
# 462     0.0  0.585323     0.0       1.0         0.0         1.0
# 136     0.0  0.233476     0.2       0.0         0.0         1.0
#
# [623 rows x 6 columns]

# %%
X_test_df
# Out:
#      Pclass       Age  family  Sex_male  Embarked_Q  Embarked_S
# 625     0.0  0.761247     0.0       1.0         0.0         1.0
# 566     1.0  0.233476     0.0       1.0         0.0         1.0
# 459     1.0  0.367921     0.0       1.0         1.0         0.0
# 804     1.0  0.334004     0.0       1.0         0.0         1.0
# 338     1.0  0.560191     0.0       1.0         0.0         1.0
# ..      ...       ...     ...       ...         ...         ...
# 184     1.0  0.044986     0.2       0.0         0.0         1.0
# 607     0.0  0.334004     0.0       1.0         0.0         1.0
# 624     1.0  0.258608     0.0       1.0         0.0         1.0
# 103     1.0  0.409399     0.0       1.0         0.0         1.0
# 387     0.5  0.447097     0.0       0.0         0.0         1.0
#
# [268 rows x 6 columns]

# %% [markdown]
# # Tensorflow Sequential API를 사용한 순차적 모델 생성 및 분석
# * Sequential: 인공신경망을 순차적으로 작성할 때 사용
# * Dense: 층, 레이어
# * 1. 신경망 모델 정의
# * 2. 신경망 모델 훈련
# * 3. 훈련된 모델로 테스트
# * 4. 검증

# %% [markdown]
# * 입력층은 반드시 독립변수의수(input_dim)를 정확히 지정
# * 신경망 모델의 은닉층은 2~3개 정도로 한다.
# * Dense의 노드수는 2의 배수의 지정 2 4 8 16 256
# * Dense의 노드는 큰 수에서 작은 수로 줄여나간다.
# * 은닉층의 활성화 함수: Relu
# * 출력층은 이진분류일 경우 sigmoid, 다중분류일 경우 softmax
# * 회귀분석일 경우(종속변수가 연속형(수치형)인 경우) 출력층에 활성화 함수 없이 노드를 1로 지정

# %%
import tensorflow as tf
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
X_train_df.shape[1]
# Out:
# 6

# %%
# 신경망 모델 정의 keras 3.0, tensroflow 2.19 기준
model = Sequential()
model.add(Input(shape=(X_train_df.shape[1],))) # 입력층
model.add(Dense(64, activation='relu'))  # 은닉층
model.add(Dense(32, activation='relu'))  # 은닉층
model.add(Dense(16, activation='relu'))  # 은닉층
model.add(Dense(1, activation='sigmoid'))  # 출력층, 이진분류이므로 sigmoid
# Out:
# 2025-12-02 13:06:16.287152: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
dtc = DecisionTreeClassifier(max_depth=3, random_state=42)
dtc.fit(X_train, y_train)

# %% [markdown]
# #  모델의 파라미터 세팅 model.compile()
# * loss: 오차 계산 지표
#   * 이진분류: binary_crossentropy
#   * 다중분류: categorical_crossentropy - y가 one-hot encoding
#   * 데이터에 0이 많은 희소행렬인 경우: sparse_categorical_crossentropy - y label encoding
#   * 연속형데이터(회귀분석): mse
# * optimizer: learning_rate
#   * adam을 가장 많이 사용
# * metrics: 평가지표 accuracy

# %%
# 모델의 파라미터 세팅
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,073 (12.00 KB)
#  Trainable params: 3,073 (12.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # 모델 훈련 model.fit(X_train, y_train)
# * epochs: 전체 데이터를 한 번 훈련하는 주기, 10-100 사이
# * batch_size: 전체 데이터를 쪼개서 훈련, 데이터의 묶음, 메모리에 맞춰서 크기 조절(2의 배수) 32, 64로 쪼개서 넣는 것 추천
# * validation_data: 검증 데이터로 모델 검증 실시

# %%
len(X_train_df)
# Out:
# 623

# %%
history = model.fit(X_train_df, y_train, epochs=100, 
                    batch_size=16, validation_data=(X_test_df, y_test))
# Out:
# Epoch 1/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6806 - loss: 0.5941 - val_accuracy: 0.8134 - val_loss: 0.5390
# Epoch 2/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7945 - loss: 0.5109 - val_accuracy: 0.7761 - val_loss: 0.4949
# Epoch 3/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7913 - loss: 0.4766 - val_accuracy: 0.7761 - val_loss: 0.4708
# Epoch 4/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7897 - loss: 0.4612 - val_accuracy: 0.8022 - val_loss: 0.4559
# Epoch 5/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7945 - loss: 0.4512 - val_accuracy: 0.8022 - val_loss: 0.4507
# Epoch 6/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8138 - loss: 0.4430 - val_accuracy: 0.8097 - val_loss: 0.4465
# Epoch 7/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8122 - loss: 0.4381 - val_accuracy: 0.8172 - val_loss: 0.4361
# Epoch 8/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8170 - loss: 0.4393 - val_accuracy: 0.8022 - val_loss: 0.4375
# Epoch 9/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8026 - loss: 0.4393 - val_accuracy: 0.7873 - val_loss: 0.4447
# Epoch 10/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8122 - loss: 0.4318 - val_accuracy: 0.8172 - val_loss: 0.4267
# Epoch 11/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8090 - loss: 0.4318 - val_accuracy: 0.8134 - val_loss: 0.4256
# Epoch 12/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8106 - loss: 0.4284 - val_accuracy: 0.7985 - val_loss: 0.4246
# Epoch 13/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8106 - loss: 0.4274 - val_accuracy: 0.8134 - val_loss: 0.4241
# Epoch 14/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8170 - loss: 0.4230 - val_accuracy: 0.7985 - val_loss: 0.4338
# Epoch 15/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8058 - loss: 0.4217 - val_accuracy: 0.8134 - val_loss: 0.4243
# Epoch 16/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8106 - loss: 0.4235 - val_accuracy: 0.8172 - val_loss: 0.4265
# Epoch 17/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8170 - loss: 0.4244 - val_accuracy: 0.8060 - val_loss: 0.4225
# Epoch 18/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8122 - loss: 0.4240 - val_accuracy: 0.8209 - val_loss: 0.4206
# Epoch 19/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8202 - loss: 0.4185 - val_accuracy: 0.8097 - val_loss: 0.4310
# Epoch 20/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8186 - loss: 0.4159 - val_accuracy: 0.8172 - val_loss: 0.4182
# Epoch 21/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8234 - loss: 0.4156 - val_accuracy: 0.7948 - val_loss: 0.4225
# Epoch 22/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8042 - loss: 0.4177 - val_accuracy: 0.8097 - val_loss: 0.4184
# Epoch 23/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8170 - loss: 0.4175 - val_accuracy: 0.8097 - val_loss: 0.4195
# Epoch 24/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8138 - loss: 0.4234 - val_accuracy: 0.8134 - val_loss: 0.4189
# Epoch 25/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8250 - loss: 0.4216 - val_accuracy: 0.8134 - val_loss: 0.4180
# Epoch 26/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8170 - loss: 0.4180 - val_accuracy: 0.8172 - val_loss: 0.4185
# Epoch 27/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8154 - loss: 0.4129 - val_accuracy: 0.8209 - val_loss: 0.4181
# Epoch 28/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8138 - loss: 0.4191 - val_accuracy: 0.8134 - val_loss: 0.4165
# Epoch 29/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8186 - loss: 0.4151 - val_accuracy: 0.8246 - val_loss: 0.4167
# Epoch 30/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8266 - loss: 0.4142 - val_accuracy: 0.8097 - val_loss: 0.4171
# Epoch 31/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8315 - loss: 0.4112 - val_accuracy: 0.8134 - val_loss: 0.4178
# Epoch 32/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8331 - loss: 0.4165 - val_accuracy: 0.8209 - val_loss: 0.4155
# Epoch 33/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8283 - loss: 0.4075 - val_accuracy: 0.7910 - val_loss: 0.4341
# Epoch 34/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8154 - loss: 0.4128 - val_accuracy: 0.8246 - val_loss: 0.4186
# Epoch 35/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8299 - loss: 0.4087 - val_accuracy: 0.8097 - val_loss: 0.4177
# Epoch 36/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8283 - loss: 0.4094 - val_accuracy: 0.8097 - val_loss: 0.4163
# Epoch 37/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8315 - loss: 0.4090 - val_accuracy: 0.8134 - val_loss: 0.4152
# Epoch 38/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8106 - loss: 0.4089 - val_accuracy: 0.8134 - val_loss: 0.4160
# Epoch 39/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8315 - loss: 0.4040 - val_accuracy: 0.7985 - val_loss: 0.4139
# Epoch 40/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8283 - loss: 0.4039 - val_accuracy: 0.8097 - val_loss: 0.4131
# Epoch 41/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8283 - loss: 0.4035 - val_accuracy: 0.8097 - val_loss: 0.4165
# Epoch 42/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8234 - loss: 0.4029 - val_accuracy: 0.8097 - val_loss: 0.4146
# Epoch 43/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8363 - loss: 0.4035 - val_accuracy: 0.7985 - val_loss: 0.4173
# Epoch 44/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8283 - loss: 0.3979 - val_accuracy: 0.7948 - val_loss: 0.4324
# Epoch 45/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8347 - loss: 0.4031 - val_accuracy: 0.8060 - val_loss: 0.4158
# Epoch 46/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8331 - loss: 0.4027 - val_accuracy: 0.8172 - val_loss: 0.4151
# Epoch 47/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8363 - loss: 0.3974 - val_accuracy: 0.8097 - val_loss: 0.4172
# Epoch 48/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8379 - loss: 0.3956 - val_accuracy: 0.8022 - val_loss: 0.4209
# Epoch 49/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8347 - loss: 0.3956 - val_accuracy: 0.8060 - val_loss: 0.4163
# Epoch 50/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8347 - loss: 0.3927 - val_accuracy: 0.8022 - val_loss: 0.4180
# Epoch 51/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8379 - loss: 0.3960 - val_accuracy: 0.7910 - val_loss: 0.4196
# Epoch 52/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8299 - loss: 0.3946 - val_accuracy: 0.8060 - val_loss: 0.4175
# Epoch 53/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8315 - loss: 0.3951 - val_accuracy: 0.7873 - val_loss: 0.4481
# Epoch 54/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8363 - loss: 0.3948 - val_accuracy: 0.8097 - val_loss: 0.4170
# Epoch 55/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8315 - loss: 0.3903 - val_accuracy: 0.7836 - val_loss: 0.4307
# Epoch 56/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8315 - loss: 0.3932 - val_accuracy: 0.7910 - val_loss: 0.4245
# Epoch 57/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.3891 - val_accuracy: 0.7948 - val_loss: 0.4238
# Epoch 58/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.3936 - val_accuracy: 0.8097 - val_loss: 0.4252
# Epoch 59/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8379 - loss: 0.3906 - val_accuracy: 0.7873 - val_loss: 0.4331
# Epoch 60/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8443 - loss: 0.3891 - val_accuracy: 0.7910 - val_loss: 0.4266
# Epoch 61/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8363 - loss: 0.3871 - val_accuracy: 0.8209 - val_loss: 0.4240
# Epoch 62/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8475 - loss: 0.3856 - val_accuracy: 0.8172 - val_loss: 0.4232
# Epoch 63/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8363 - loss: 0.3857 - val_accuracy: 0.8209 - val_loss: 0.4226
# Epoch 64/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8379 - loss: 0.3847 - val_accuracy: 0.8097 - val_loss: 0.4287
# Epoch 65/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.3863 - val_accuracy: 0.8209 - val_loss: 0.4241
# Epoch 66/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8363 - loss: 0.3837 - val_accuracy: 0.8246 - val_loss: 0.4278
# Epoch 67/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8411 - loss: 0.3910 - val_accuracy: 0.7836 - val_loss: 0.4427
# Epoch 68/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.3879 - val_accuracy: 0.7873 - val_loss: 0.4363
# Epoch 69/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8411 - loss: 0.3841 - val_accuracy: 0.8209 - val_loss: 0.4295
# Epoch 70/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8411 - loss: 0.3852 - val_accuracy: 0.7948 - val_loss: 0.4335
# Epoch 71/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8299 - loss: 0.3850 - val_accuracy: 0.7948 - val_loss: 0.4441
# Epoch 72/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8379 - loss: 0.3829 - val_accuracy: 0.8209 - val_loss: 0.4317
# Epoch 73/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8411 - loss: 0.3828 - val_accuracy: 0.7799 - val_loss: 0.4421
# Epoch 74/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8491 - loss: 0.3823 - val_accuracy: 0.8246 - val_loss: 0.4341
# Epoch 75/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8331 - loss: 0.3800 - val_accuracy: 0.8134 - val_loss: 0.4379
# Epoch 76/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8379 - loss: 0.3828 - val_accuracy: 0.8172 - val_loss: 0.4362
# Epoch 77/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8331 - loss: 0.3862 - val_accuracy: 0.8172 - val_loss: 0.4380
# Epoch 78/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8379 - loss: 0.3807 - val_accuracy: 0.8209 - val_loss: 0.4363
# Epoch 79/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8395 - loss: 0.3799 - val_accuracy: 0.8209 - val_loss: 0.4418
# Epoch 80/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8379 - loss: 0.3781 - val_accuracy: 0.8097 - val_loss: 0.4349
# Epoch 81/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8427 - loss: 0.3792 - val_accuracy: 0.8209 - val_loss: 0.4363
# Epoch 82/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8443 - loss: 0.3778 - val_accuracy: 0.8134 - val_loss: 0.4404
# Epoch 83/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8347 - loss: 0.3793 - val_accuracy: 0.7761 - val_loss: 0.4497
# Epoch 84/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8427 - loss: 0.3778 - val_accuracy: 0.7910 - val_loss: 0.4512
# Epoch 85/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8395 - loss: 0.3780 - val_accuracy: 0.8209 - val_loss: 0.4403
# Epoch 86/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8459 - loss: 0.3801 - val_accuracy: 0.8172 - val_loss: 0.4408
# Epoch 87/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8411 - loss: 0.3776 - val_accuracy: 0.7985 - val_loss: 0.4471
# Epoch 88/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8347 - loss: 0.3790 - val_accuracy: 0.8134 - val_loss: 0.4442
# Epoch 89/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8411 - loss: 0.3763 - val_accuracy: 0.8246 - val_loss: 0.4431
# Epoch 90/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8459 - loss: 0.3754 - val_accuracy: 0.8172 - val_loss: 0.4439
# Epoch 91/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8331 - loss: 0.3762 - val_accuracy: 0.7836 - val_loss: 0.4514
# Epoch 92/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8427 - loss: 0.3738 - val_accuracy: 0.8060 - val_loss: 0.4529
# Epoch 93/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8379 - loss: 0.3753 - val_accuracy: 0.8321 - val_loss: 0.4475
# Epoch 94/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8395 - loss: 0.3750 - val_accuracy: 0.8209 - val_loss: 0.4476
# Epoch 95/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8347 - loss: 0.3793 - val_accuracy: 0.8284 - val_loss: 0.4470
# Epoch 96/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8315 - loss: 0.3785 - val_accuracy: 0.7836 - val_loss: 0.4553
# Epoch 97/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8411 - loss: 0.3780 - val_accuracy: 0.8284 - val_loss: 0.4545
# Epoch 98/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8443 - loss: 0.3771 - val_accuracy: 0.8134 - val_loss: 0.4485
# Epoch 99/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8507 - loss: 0.3761 - val_accuracy: 0.7985 - val_loss: 0.4539
# Epoch 100/100
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8395 - loss: 0.3721 - val_accuracy: 0.8134 - val_loss: 0.4497

# %% [markdown]
# # 딥러닝 모델 성능 평가
# * 딥러닝에서 모델의 성능을 평가하는 지표는 loss
# * 보통 loss가 낮으면 accuracy가 올라가지만 비례하지 않을 때도 있음.
# * accuracy와 loss 간의 차이가 있을 때 loss가 낮은 모델이 우수한 모델

# %%
score = model.evaluate(X_test_df, y_test)
print('test_loss: ', score[0])
print('test accuracy: ', score[1])
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8134 - loss: 0.4497
# test_loss:  0.449691504240036
# test accuracy:  0.8134328126907349

# %%
for i in history.history:
    print(f"{i}: ", history.history[i])
# Out:
# accuracy:  [0.6805778741836548, 0.7945425510406494, 0.7913322448730469, 0.7897271513938904, 0.7945425510406494, 0.8138041496276855, 0.812199056148529, 0.8170144557952881, 0.8025681972503662, 0.812199056148529, 0.8089887499809265, 0.8105939030647278, 0.8105939030647278, 0.8170144557952881, 0.8057785034179688, 0.8105939030647278, 0.8170144557952881, 0.812199056148529, 0.8202247023582458, 0.8186196088790894, 0.8234350085258484, 0.8041733503341675, 0.8170144557952881, 0.8138041496276855, 0.8250401020050049, 0.8170144557952881, 0.8154093027114868, 0.8138041496276855, 0.8186196088790894, 0.8266452550888062, 0.8314606547355652, 0.8330658078193665, 0.8282504081726074, 0.8154093027114868, 0.8298555612564087, 0.8282504081726074, 0.8314606547355652, 0.8105939030647278, 0.8314606547355652, 0.8282504081726074, 0.8282504081726074, 0.8234350085258484, 0.8362760543823242, 0.8282504081726074, 0.8346709609031677, 0.8330658078193665, 0.8362760543823242, 0.8378812074661255, 0.8346709609031677, 0.8346709609031677, 0.8378812074661255, 0.8298555612564087, 0.8314606547355652, 0.8362760543823242, 0.8314606547355652, 0.8314606547355652, 0.8394863605499268, 0.8394863605499268, 0.8378812074661255, 0.8443017601966858, 0.8362760543823242, 0.8475120663642883, 0.8362760543823242, 0.8378812074661255, 0.8394863605499268, 0.8362760543823242, 0.841091513633728, 0.8394863605499268, 0.841091513633728, 0.841091513633728, 0.8298555612564087, 0.8378812074661255, 0.841091513633728, 0.8491171598434448, 0.8330658078193665, 0.8378812074661255, 0.8330658078193665, 0.8378812074661255, 0.8394863605499268, 0.8378812074661255, 0.8426966071128845, 0.8443017601966858, 0.8346709609031677, 0.8426966071128845, 0.8394863605499268, 0.8459069132804871, 0.841091513633728, 0.8346709609031677, 0.841091513633728, 0.8459069132804871, 0.8330658078193665, 0.8426966071128845, 0.8378812074661255, 0.8394863605499268, 0.8346709609031677, 0.8314606547355652, 0.841091513633728, 0.8443017601966858, 0.8507223129272461, 0.8394863605499268]
# loss:  [0.5941470861434937, 0.5109298229217529, 0.4765675961971283, 0.46120524406433105, 0.4511987268924713, 0.4430258274078369, 0.4381093680858612, 0.4393044114112854, 0.43932124972343445, 0.4317605793476105, 0.43177279829978943, 0.42842796444892883, 0.4273584187030792, 0.4229808747768402, 0.4217279553413391, 0.4234740138053894, 0.4243782162666321, 0.42397022247314453, 0.41845938563346863, 0.4159073829650879, 0.41559216380119324, 0.41769394278526306, 0.41745680570602417, 0.42337825894355774, 0.42156997323036194, 0.41800346970558167, 0.4129435420036316, 0.4190516471862793, 0.41508132219314575, 0.4142332077026367, 0.41117748618125916, 0.41652172803878784, 0.40752702951431274, 0.41275322437286377, 0.408743679523468, 0.40935778617858887, 0.40900981426239014, 0.40893125534057617, 0.4039880633354187, 0.4038844704627991, 0.40347206592559814, 0.40294837951660156, 0.4034704864025116, 0.39787358045578003, 0.403145968914032, 0.40265917778015137, 0.3973948359489441, 0.3956291377544403, 0.39562010765075684, 0.39274922013282776, 0.39603033661842346, 0.39457714557647705, 0.39511966705322266, 0.3947707712650299, 0.39028969407081604, 0.3932245671749115, 0.3891403079032898, 0.39357221126556396, 0.3905506134033203, 0.3890821039676666, 0.3871321976184845, 0.38563457131385803, 0.3857322335243225, 0.38474562764167786, 0.3862752914428711, 0.3837301731109619, 0.39095228910446167, 0.3879358172416687, 0.38414740562438965, 0.38520312309265137, 0.3849797546863556, 0.382913202047348, 0.38279175758361816, 0.3822501599788666, 0.38002142310142517, 0.3827691078186035, 0.38616135716438293, 0.3807065486907959, 0.37994205951690674, 0.3781459629535675, 0.37917354702949524, 0.3777773380279541, 0.37928545475006104, 0.3777909278869629, 0.3779953718185425, 0.3801388740539551, 0.37761202454566956, 0.3789573311805725, 0.3762851655483246, 0.37542009353637695, 0.3762214481830597, 0.3738023340702057, 0.3752598464488983, 0.37501078844070435, 0.3793349266052246, 0.3784742057323456, 0.3779844641685486, 0.3771000802516937, 0.3760782778263092, 0.3721134066581726]
# val_accuracy:  [0.8134328126907349, 0.7761194109916687, 0.7761194109916687, 0.8022388219833374, 0.8022388219833374, 0.8097015023231506, 0.8171641826629639, 0.8022388219833374, 0.7873134613037109, 0.8171641826629639, 0.8134328126907349, 0.7985074520111084, 0.8134328126907349, 0.7985074520111084, 0.8134328126907349, 0.8171641826629639, 0.8059701323509216, 0.8208954930305481, 0.8097015023231506, 0.8171641826629639, 0.7947761416435242, 0.8097015023231506, 0.8097015023231506, 0.8134328126907349, 0.8134328126907349, 0.8171641826629639, 0.8208954930305481, 0.8134328126907349, 0.8246268630027771, 0.8097015023231506, 0.8134328126907349, 0.8208954930305481, 0.7910447716712952, 0.8246268630027771, 0.8097015023231506, 0.8097015023231506, 0.8134328126907349, 0.8134328126907349, 0.7985074520111084, 0.8097015023231506, 0.8097015023231506, 0.8097015023231506, 0.7985074520111084, 0.7947761416435242, 0.8059701323509216, 0.8171641826629639, 0.8097015023231506, 0.8022388219833374, 0.8059701323509216, 0.8022388219833374, 0.7910447716712952, 0.8059701323509216, 0.7873134613037109, 0.8097015023231506, 0.7835820913314819, 0.7910447716712952, 0.7947761416435242, 0.8097015023231506, 0.7873134613037109, 0.7910447716712952, 0.8208954930305481, 0.8171641826629639, 0.8208954930305481, 0.8097015023231506, 0.8208954930305481, 0.8246268630027771, 0.7835820913314819, 0.7873134613037109, 0.8208954930305481, 0.7947761416435242, 0.7947761416435242, 0.8208954930305481, 0.7798507213592529, 0.8246268630027771, 0.8134328126907349, 0.8171641826629639, 0.8171641826629639, 0.8208954930305481, 0.8208954930305481, 0.8097015023231506, 0.8208954930305481, 0.8134328126907349, 0.7761194109916687, 0.7910447716712952, 0.8208954930305481, 0.8171641826629639, 0.7985074520111084, 0.8134328126907349, 0.8246268630027771, 0.8171641826629639, 0.7835820913314819, 0.8059701323509216, 0.8320895433425903, 0.8208954930305481, 0.8283582329750061, 0.7835820913314819, 0.8283582329750061, 0.8134328126907349, 0.7985074520111084, 0.8134328126907349]
# val_loss:  [0.5390110015869141, 0.4948732852935791, 0.4707591235637665, 0.4559379816055298, 0.4506675899028778, 0.44646868109703064, 0.43609514832496643, 0.4374999701976776, 0.44465675950050354, 0.42665302753448486, 0.4256317913532257, 0.4246378540992737, 0.42409417033195496, 0.4338107407093048, 0.4242953658103943, 0.4264872968196869, 0.4225353002548218, 0.42056554555892944, 0.4310469925403595, 0.41822105646133423, 0.42253199219703674, 0.41835829615592957, 0.4194749593734741, 0.418891042470932, 0.41798222064971924, 0.4184577167034149, 0.4180960953235626, 0.4165143072605133, 0.41670969128608704, 0.417134553194046, 0.41784748435020447, 0.41554832458496094, 0.434053897857666, 0.41856786608695984, 0.41773858666419983, 0.4162848889827728, 0.4152058959007263, 0.4160254895687103, 0.413897305727005, 0.4130888283252716, 0.41654151678085327, 0.41457363963127136, 0.41733890771865845, 0.43239346146583557, 0.4157584011554718, 0.41511258482933044, 0.41715171933174133, 0.42092210054397583, 0.4162707030773163, 0.41795340180397034, 0.41961899399757385, 0.4175439774990082, 0.44814804196357727, 0.4169815182685852, 0.4307297468185425, 0.4245258569717407, 0.4237804710865021, 0.4252433776855469, 0.4331316649913788, 0.42657819390296936, 0.4239620268344879, 0.42319419980049133, 0.4225917458534241, 0.42867371439933777, 0.42412611842155457, 0.42781689763069153, 0.44270873069763184, 0.4363185465335846, 0.42950811982154846, 0.4334769546985626, 0.44409096240997314, 0.4317457377910614, 0.4421415328979492, 0.43407800793647766, 0.4378627836704254, 0.43621957302093506, 0.4380202889442444, 0.43629777431488037, 0.44183874130249023, 0.4349295198917389, 0.4363200068473816, 0.4404110312461853, 0.4497188329696655, 0.45122042298316956, 0.44027453660964966, 0.44082990288734436, 0.4470760226249695, 0.4442470967769623, 0.44309040904045105, 0.4439183175563812, 0.4513949453830719, 0.452875554561615, 0.44745808839797974, 0.4476344883441925, 0.44704470038414, 0.45529893040657043, 0.4544925391674042, 0.4485035836696625, 0.45387375354766846, 0.4496914744377136]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel("epoches")
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
