# %% [markdown]
# # Pandas 활용하기
# * 데이터분석에 특화된 데이터구조를 제공하는 라이브러리(테이블 형태의 DataFrame, 리스트 형태의 Series)
# * 다양한 데이터 분석 함수 제공
# * 데이터베이스에서 쉽게 자료를 가져올 수 있음
# * json, csv, excel, html의 table 요소 등 다양한 데이터를 불러올 수 있음
# * numpy를 내부적으로 사용, numpy와 pandas간 변환이 쉬움
# https://pandas.pydata.org/docs/index.html

# %% [markdown]
# # pandas 에서 다루는 데이터 타입 2가지
# ## 1) DataFrame: 2차원 형태의 표형식 데이터
# * python의 dict를 기반 으로 만들어진 데이터 하나의 key에 리스트 자료가 value로 들어간 형태
# * {key1: [value1, value2, value3], key2: [value1, value2, value3]}
# * key는 데이터프레임의 컬럼명이 됨, value는 컬럼의 자료
# * 데이터프레임은 python의 dict 사용법과 거의 비슷

# %% [markdown]
# ## 2) Series: 1차원 형태의 벡터형식 데이터
# * python의 list, tuple, ndarray의 1차원 상태와 비슷
# * 이름이 있는 list
# * list 사용법과 비슷, 인덱싱, 슬라이싱가능, 반복문 사용 가능

# %%
import pandas as pd

# %% [markdown]
# # 데이터 프레임 만들기
# pd.DataFrame({key1: [value1, value2, value3], key2: [value1, value2, value3]})

# %%
df = pd.DataFrame(
    {'이름' : ['홍길동','둘리','또치','도우너'],
     '주소' : ['서울','의정부','고양시','성남시'],
    '취미' : ['음악감상','놀기','달리기','바이올린']}
)

# %%
df
# Out:
#     이름   주소    취미
# 0  홍길동   서울  음악감상
# 1   둘리  의정부    놀기
# 2   또치  고양시   달리기
# 3  도우너  성남시  바이올린

# %% [markdown]
# # 넘파이 기반으로 만들어졌기 때문에 넘파이 메서드 사용 가능

# %%
df.shape
# Out:
# (4, 3)

# %%
df.ndim
# Out:
# 2

# %%
arr = df.to_numpy()
arr
# Out:
# array([['홍길동', '서울', '음악감상'],
#        ['둘리', '의정부', '놀기'],
#        ['또치', '고양시', '달리기'],
#        ['도우너', '성남시', '바이올린']], dtype=object)

# %%
df.columns
# Out:
# Index(['이름', '주소', '취미'], dtype='object')

# %%
pd.DataFrame(arr, columns=df.columns)
# Out:
#     이름   주소    취미
# 0  홍길동   서울  음악감상
# 1   둘리  의정부    놀기
# 2   또치  고양시   달리기
# 3  도우너  성남시  바이올린

# %% [markdown]
# # 데이터 프레임 슬라이싱, .loc(인덱스명, 컬럼이름), .iloc(행인덱스, 열인덱스)

# %%
df.iloc[:2, :2]
# Out:
#     이름   주소
# 0  홍길동   서울
# 1   둘리  의정부

# %% [markdown]
# # 데이터 프레임에서 컬럼 1개만 출력할 때
# 변수명[컬럼명]

# %%
list(df['이름'])
# Out:
# ['홍길동', '둘리', '또치', '도우너']

# %%
d = {'이름' : ['홍길동','둘리','또치','도우너'],
     '주소' : ['서울','의정부','고양시','성남시'],
    '취미' : ['음악감상','놀기','달리기','바이올린']}

# %%
d
# Out:
# {'이름': ['홍길동', '둘리', '또치', '도우너'],
#  '주소': ['서울', '의정부', '고양시', '성남시'],
#  '취미': ['음악감상', '놀기', '달리기', '바이올린']}

# %%
d['이름']
# Out:
# ['홍길동', '둘리', '또치', '도우너']

# %%
for name in df['이름']:
    print(name)
# Out:
# 홍길동
# 둘리
# 또치
# 도우너

# %%
df['이름'][1]
# Out:
# '둘리'

# %% [markdown]
# # 컬럼을 2개 이상 잘라 오고 싶을 때

# %%
df[['이름', '취미']]
# Out:
#     이름    취미
# 0  홍길동  음악감상
# 1   둘리    놀기
# 2   또치   달리기
# 3  도우너  바이올린

# %% [markdown]
# # 컬럼 순서를 바꾸고 싶을 때

# %%
df
# Out:
#     이름   주소    취미
# 0  홍길동   서울  음악감상
# 1   둘리  의정부    놀기
# 2   또치  고양시   달리기
# 3  도우너  성남시  바이올린

# %%
df[['취미', '이름', '주소']]
# Out:
#      취미   이름   주소
# 0  음악감상  홍길동   서울
# 1    놀기   둘리  의정부
# 2   달리기   또치  고양시
# 3  바이올린  도우너  성남시

# %%
df
# Out:
#     이름   주소    취미
# 0  홍길동   서울  음악감상
# 1   둘리  의정부    놀기
# 2   또치  고양시   달리기
# 3  도우너  성남시  바이올린

# %% [markdown]
# # Series 만들기
# * pd.Series([리스트/튜플], name="컬럼명")
# * 이름을 가지고 있는 list/벡터
# * DataFrame에서 컬럼 1개를 잘라온 형태

# %%
ages = pd.Series([22, 33, 53], name="나이")
ages
# Out:
# 0    22
# 1    33
# 2    53
# Name: 나이, dtype: int64

# %%
ages.dtype
# Out:
# dtype('int64')

# %%
ages.shape
# Out:
# (3,)

# %%
ages.ndim
# Out:
# 1

# %%
ages[1:3]
# Out:
# 1    33
# 2    53
# Name: 나이, dtype: int64

# %%
ages[::-1]
# Out:
# 2    53
# 1    33
# 0    22
# Name: 나이, dtype: int64

# %%
ages.min()
# Out:
# np.int64(22)

# %%
ages.max()
# Out:
# np.int64(53)

# %%
ages.sum()
# Out:
# np.int64(108)

# %%
ages.cumsum()
# Out:
# 0     22
# 1     55
# 2    108
# Name: 나이, dtype: int64

# %%
ages.mean()
# Out:
# np.float64(36.0)

# %%
ages.median()
# Out:
# np.float64(33.0)

# %% [markdown]
# # 판다스에서 자료 불러오기, 저장하기
# * csv, tsv, excel, json, html, sql
# * pd.read_확장자명(파일경로, 옵션)

# %% [markdown]
# # excel 파일 불러오기
# * xls, xlsx 두가지 파일 형식이 있음
# * excel 파일을 불러올 때는 openpyxl 라이브러리를 따로 설치
# ```python
# !pip install openpyxl
# ```

# %%
# !pip install openpyxl

# %% [markdown]
# excel 파일은 loading 시간이 오래 걸림

# %%
# %%time
df_excel = pd.read_excel("./data/Online Retail.xlsx")
df_excel
# Out:
# CPU times: total: 1min 1s
# Wall time: 1min 1s
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df_excel2 = pd.read_excel("./data/아파트(매매)_실거래가_20240806113828.xlsx", header=12)
df_excel2
# Out:
# C:\Users\haram4th\miniforge3\envs\fintech\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           NO                  시군구      번지    본번  부번                단지명  \
# 0          1     서울특별시 영등포구 당산동5가      42    42   0          당산삼성래미안4차
# 1          2  강원특별자치도 원주시 지정면 가곡리    1512  1512   0  원주롯데캐슬골드파크1차(5단지)
# 2          3    대구광역시 달성군 화원읍 구라리    1650  1650   0             대곡역래미안
# 3          4         광주광역시 남구 진월동   312-7   312   7                 광명
# 4          5         광주광역시 남구 진월동  331-93   331  93                 중흥
# ...      ...                  ...     ...   ...  ..                ...
# 37575  37576        서울특별시 송파구 장지동     849   849   0          송파파인타운3단지
# 37576  37577        부산광역시 사상구 모라동     552   552   0               백양그린
# 37577  37578        광주광역시 광산구 비아동   152-5   152   5                 호반
# 37578  37579        부산광역시 사상구 모라동     552   552   0               백양그린
# 37579  37580         대구광역시 북구 읍내동  1366-2  1366   2               칠곡보성
#
#         전용면적(㎡)    계약년월  계약일 거래금액(만원)  ...   층  매수자 매도자  건축년도            도로명  \
# 0      115.7800  202407   31  139,000  ...   4   개인  개인  2003        당산로 214
# 1       84.9644  202407   31   38,900  ...  10   개인  개인  2019       신지정로 250
# 2       84.5958  202407   31   29,500  ...  11   개인  개인  2007     비슬로539길 35
# 3       70.6250  202407   31   16,900  ...   1   개인  개인  1998       광복마을길 63
# 4       84.8400  202407   31   17,500  ...  13   개인  개인  1992  서문대로749번마길 30
# ...         ...     ...  ...      ...  ...  ..  ...  ..   ...            ...
# 37575   84.9800  202407    1  117,500  ...  14   개인  개인  2008        충민로 152
# 37576   41.3000  202407    1    7,000  ...   8   개인  개인  1992    모라로110번길 88
# 37577   59.8800  202407    1   15,400  ...   5   개인  개인  1998        비아로 185
# 37578   41.3000  202407    1    7,500  ...  10   개인  개인  1992    모라로110번길 88
# 37579   84.9800  202407    1   21,000  ...   9   개인  개인  1992      구암로21길 26
#
#         해제사유발생일  거래유형  중개사소재지      등기일자 주택유형
# 0             -   직거래       -         -  아파트
# 1      20240802  중개거래  강원 원주시         -  아파트
# 2             -  중개거래  대구 달성군         -  아파트
# 3             -  중개거래   광주 남구         -  아파트
# 4             -   직거래       -  24.07.31  아파트
# ...         ...   ...     ...       ...  ...
# 37575         -  중개거래  서울 송파구         -  아파트
# 37576         -  중개거래  부산 사상구  24.07.10  아파트
# 37577         -  중개거래  광주 광산구  24.07.26  아파트
# 37578         -  중개거래  부산 사상구  24.07.19  아파트
# 37579         -  중개거래   대구 북구         -  아파트
#
# [37580 rows x 21 columns]

# %% [markdown]
# # csv 파일 읽어오기 ( , 로 구분된 자료가 있는 파일)

# %%
# %%time
df_csv = pd.read_csv("./data/Online Retail.csv")
df_csv
# Out:
# CPU times: total: 578 ms
# Wall time: 611 ms
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 0       2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1       2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2       2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3       2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4       2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                     ...        ...         ...             ...
# 541904  2011-12-09 12:50:00       0.85     12680.0          France
# 541905  2011-12-09 12:50:00       2.10     12680.0          France
# 541906  2011-12-09 12:50:00       4.15     12680.0          France
# 541907  2011-12-09 12:50:00       4.15     12680.0          France
# 541908  2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df_csv2 = pd.read_csv("./data/아파트(매매)_실거래가_20240806113828.csv", header=12, usecols=[1, 5, 6, 7 , 8, 9])
df_csv2
# Out:
#                        시군구                단지명   전용면적(㎡)    계약년월  계약일 거래금액(만원)
# 0         서울특별시 영등포구 당산동5가          당산삼성래미안4차  115.7800  202407   31  139,000
# 1      강원특별자치도 원주시 지정면 가곡리  원주롯데캐슬골드파크1차(5단지)   84.9644  202407   31   38,900
# 2        대구광역시 달성군 화원읍 구라리             대곡역래미안   84.5958  202407   31   29,500
# 3             광주광역시 남구 진월동                 광명   70.6250  202407   31   16,900
# 4             광주광역시 남구 진월동                 중흥   84.8400  202407   31   17,500
# ...                    ...                ...       ...     ...  ...      ...
# 37575        서울특별시 송파구 장지동          송파파인타운3단지   84.9800  202407    1  117,500
# 37576        부산광역시 사상구 모라동               백양그린   41.3000  202407    1    7,000
# 37577        광주광역시 광산구 비아동                 호반   59.8800  202407    1   15,400
# 37578        부산광역시 사상구 모라동               백양그린   41.3000  202407    1    7,500
# 37579         대구광역시 북구 읍내동               칠곡보성   84.9800  202407    1   21,000
#
# [37580 rows x 6 columns]

# %% [markdown]
# # json 파일 읽어오기

# %%
df_json = pd.read_json("./data/서울특별시_관광지입장정보_2011_2016.json")
df_json
# Out:
#     ForNum  NatNum  addrCd gungu      resNm  rnum   sido  yyyymm
# 0    44722   75991    1111   종로구        창덕궁     1  서울특별시  201112
# 1        0   11017    1111   종로구        운현궁     2  서울특별시  201112
# 2   132399  237330    1111   종로구        경복궁     3  서울특별시  201112
# 3     3133   21267    1111   종로구        창경궁     4  서울특별시  201112
# 4    18226   24223    1111   종로구         종묘     5  서울특별시  201112
# ..     ...     ...     ...   ...        ...   ...    ...     ...
# 62    5588   44232    1141  서대문구  서대문형무소역사관     8  서울특별시  201512
# 63       0   22587    1141  서대문구  서대문자연사박물관     9  서울특별시  201512
# 64   29520    8822    1144   마포구    트릭아이미술관    10  서울특별시  201512
# 65       3    1647    1165   서초구      헌릉ㆍ인릉    11  서울특별시  201512
# 66     492   14454    1168   강남구      선릉·정릉    12  서울특별시  201512
#
# [67 rows x 8 columns]

# %% [markdown]
# # HTML에서 table 데이터 읽어오기

# %%
df_html = pd.read_html("./data/corpList.htm")
df_html[0]
# Out:
#     Unnamed: 0                             Unnamed: 1  \
# 0     한국제15호스팩                             금융 지원 서비스업
# 1       에스오에스랩  측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 2   미래에셋비전스팩6호                             금융 지원 서비스업
# 3   에이치엠씨제7호스팩                             금융 지원 서비스업
# 4        파라다이스                     유원지 및 기타 오락관련 서비스업
# 5       한중엔시에스      전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 6     KB제29호스팩                             금융 지원 서비스업
# 7   미래에셋비전스팩5호                             금융 지원 서비스업
# 8     씨어스테크놀로지                             의료용 기기 제조업
# 9     한국제14호스팩                             금융 지원 서비스업
# 10   디비금융스팩12호                                 기타 금융업
# 11        라메디텍                             의료용 기기 제조업
# 12       그리드위즈                 그외 기타 전문, 과학 및 기술 서비스업
# 13       다원넥스뷰                        사진장비 및 광학기기 제조업
# 14  미래에셋비전스팩4호                             금융 지원 서비스업
#
#                                            Unnamed: 2  Unnamed: 3 Unnamed: 4  \
# 0                                              기업인수합병  2024-06-26        12월
# 1                                산업용 및 차량용 라이다(LiDAR)  2024-06-25        12월
# 2                                              기업인수합병  2024-06-24        12월
# 3                                                기타금융  2024-06-24        12월
# 4                                      카지노, 호텔, 복합리조트  2024-06-24        12월
# 5   수냉식 냉각시스템 ESS Parts, 공랭식 ESS Module Parts, EV ...  2024-06-24        12월
# 6                                              기업인수합병  2024-06-21        12월
# 7                                              기업인수합병  2024-06-19        12월
# 8                                심전도검사솔루션 입원환자모니터링솔루션  2024-06-19        12월
# 9                                              기업인수합병  2024-06-19        12월
# 10                                          기업인수 및 합병  2024-06-18        12월
# 11                                초소형 레이저 의료기기 및 미용기기  2024-06-17        12월
# 12                             수요관리 서비스, 전기차 충전기 모뎀 등  2024-06-14        12월
# 13                   LSMB(Laser Micro Bonding System)  2024-06-11        12월
# 14                                  기업인수목적회사(기타금융서비스)  2024-05-29        12월
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0          유한        NaN      서울특별시
# 1         정지성    홈페이지 보기      광주광역시
# 2         정명훈        NaN      서울특별시
# 3         강신명        NaN      서울특별시
# 4       최종환..    홈페이지 보기      서울특별시
# 5         김환식    홈페이지 보기       경상북도
# 6         서영화        NaN      서울특별시
# 7         김대호        NaN      서울특별시
# 8         이영신    홈페이지 보기        경기도
# 9         변성환        NaN      서울특별시
# 10        김창희        NaN      서울특별시
# 11        최종석        NaN      서울특별시
# 12        김구환    홈페이지 보기        경기도
# 13        남기중    홈페이지 보기        경기도
# 14        김정수        NaN      서울특별시

# %% [markdown]
# # DB에서 자료 읽어오기

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

# %%
# !pip install cryptography

# %%
engine = create_engine("mysql+pymysql://root:1234@localhost:3306/ex_rate")
conn = engine.connect()
df_sql = pd.read_sql("ex_rate", con=conn)
conn.close()
df_sql
# Out:
#             날짜               통화  현찰_사실_때_환율  현찰_사실_때_Spread  현찰_파실_때_환율  \
# 0   2025-10-23           미국 USD     1460.51            1.75     1410.29
# 1   2025-10-23     일본 JPY (100)      955.17            1.75      922.33
# 2   2025-10-23           유로 EUR     1699.59            1.99     1633.27
# 3   2025-10-23           중국 CNY      211.48            5.00      191.34
# 4   2025-10-23           홍콩 HKD      188.30            1.97      181.04
# 5   2025-10-23           태국 THB       45.97            5.00       41.17
# 6   2025-10-23           대만 TWD       52.69           13.10       41.94
# 7   2025-10-23          필리핀 PHP       26.92           10.00       22.48
# 8   2025-10-23         싱가포르 SGD     1126.94            1.99     1082.98
# 9   2025-10-23           호주 AUD      952.63            1.97      915.83
# 10  2025-10-23    베트남 VND (100)        6.09           11.80        4.81
# 11  2025-10-23           영국 GBP     1949.83            1.97     1874.51
# 12  2025-10-23          캐나다 CAD     1046.00            1.97     1005.60
# 13  2025-10-23        말레이시아 MYR      364.83            7.40      314.57
# 14  2025-10-23          러시아 RUB       19.33            9.50       14.57
# 15  2025-10-23        남아공화국 ZAR       89.43            8.00       76.19
# 16  2025-10-23         노르웨이 NOK      148.56            3.30      135.63
# 17  2025-10-23         뉴질랜드 NZD      841.61            1.97      809.11
# 18  2025-10-23          덴마크 DKK      230.46            3.30      210.39
# 19  2025-10-23          멕시코 MXN       86.19           10.50       69.81
# 20  2025-10-23           몽골 MNT        0.00            0.00        0.00
# 21  2025-10-23          바레인 BHD     4051.31            6.40     3503.02
# 22  2025-10-23        방글라데시 BDT        0.00            0.00        0.00
# 23  2025-10-23          브라질 BRL      293.80           10.20      239.95
# 24  2025-10-23         브루나이 BND     1149.15            4.00     1038.67
# 25  2025-10-23      사우디아라비아 SAR      406.84            6.30      356.33
# 26  2025-10-23         스리랑카 LKR        0.00            0.00        0.00
# 27  2025-10-23          스웨덴 SEK      157.92            3.30      144.17
# 28  2025-10-23          스위스 CHF     1839.36            1.97     1768.30
# 29  2025-10-23    아랍에미리트공화국 AED      412.29            5.50      363.84
# 30  2025-10-23          알제리 DZD        0.00            0.00        0.00
.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 데이터의 일부만 보기 head(), tail()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(60)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# 26           27         0       3
# 27           28         0       1
# 28           29         1       3
# 29           30         0       3
# 30           31         0       1
# 31           32         1       1
# 32           33         1       3
# 33           34         0       2
# 34           35         0       1
# 35           36         0       1
# 36           37         1       3
# 37           38         0       3
# 38           39         0       3
# 39           40         1       3
# 40           41         0       3
# 41           42         0       2
# 42           43         0       3
# 43           44         1       2
# 44           45         1       3
# 45           46         0       3
# 46           47         0       3
# 47           48         1       3
# 48           49         0       3
# 49           50         0       3
# 50           51         0       3
# 51           52         0       3
# 52           53         1       1
# 53           54         1       2
# 54           55         0       1
# 55           56         1       1
# 56           57         1       2
# 57           58         0       3
# 58           59         1       2
# 59           60         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 16                               Rice, Master. Eugene    male   2.0      4
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 21                              Beesley, Mr. Lawrence    male  34.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 26                            Emir, Mr. Farred Chehab    male   NaN      0
# 27                     Fortune, Mr. Charles Alexander    male  19.0      3
# 28                      O'Dwyer, Miss. Ellen "Nellie"  female   NaN      0
# 29                                Todoroff, Mr. Lalio    male   NaN      0
# 30                           Uruchurtu, Don. Manuel E    male  40.0      0
# 31     Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 32                           Glynn, Miss. Mary Agatha  female   NaN      0
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 34                            Meyer, Mr. Edgar Joseph    male  28.0      1
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 36                                   Mamee, Mr. Hanna    male   NaN      0
# 37                           Cann, Mr. Ernest Charles    male  21.0      0
# 38                 Vander Planke, Miss. Augusta Maria  female  18.0      2
# 39                        Nicola-Yarred, Miss. Jamila  female  14.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# 41  Turpin, Mrs. William John Robert (Dorothy Ann ...  female  27.0      1
# 42                                Kraeff, Mr. Theodor    male   NaN      0
# 43           Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 44                      Devaney, Miss. Margaret Delia  female  19.0      0
# 45                           Rogers, Mr. William John    male   NaN      0
# 46                                  Lennon, Mr. Denis    male   NaN      1
# 47                          O'Driscoll, Miss. Bridget  female   NaN      0
# 48                                Samaan, Mr. Youssef    male   NaN      2
# 49      Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# 50                         Panula, Master. Juha Niilo    male   7.0      4
# 51                       Nosworthy, Mr. Richard Cater    male  21.0      0
# 52           Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# 53  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29.0      1
# 54                     Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 55                                  Woolner, Mr. Hugh    male   NaN      0
# 56                                  Rugg, Miss. Emily  female  21.0      0
# 57                                Novel, Mr. Mansouer    male  28.5      0
# 58                       West, Miss. Constance Mirium  female   5.0      1
# 59                 Goodwin, Master. William Frederick    male  11.0      5
#
#     Parch            Ticket      Fare        Cabin Embarked
# 0       0         A/5 21171    7.2500          NaN        S
# 1       0          PC 17599   71.2833          C85        C
# 2       0  STON/O2. 3101282    7.9250          NaN        S
# 3       0            113803   53.1000         C123        S
# 4       0            373450    8.0500          NaN        S
# 5       0            330877    8.4583          NaN        Q
# 6       0             17463   51.8625          E46        S
# 7       1            349909   21.0750          NaN        S
# 8       2            347742   11.1333          NaN        S
# 9       0            237736   30.0708          NaN        C
# 10      1           PP 9549   16.7000           G6        S
# 11      0            113783   26.5500         C103        S
# 12      0         A/5. 2151    8.0500          NaN        S
# 13      5            347082   31.2750          NaN        S
# 14      0            350406    7.8542          NaN        S
# 15      0            248706   16.0000          NaN        S
# 16      1            382652   29.1250          NaN        Q
# 17      0            244373   13.0000          NaN        S
# 18      0            345763   18.0000          NaN        S
# 19      0              2649    7.2250          NaN        C
# 20      0            239865   26.0000          NaN        S
# 21      0            248698   13.0000          D56        S
# 22      0            330923    8.0292          NaN        Q
# 23      0            113788   35.5000           A6        S
# 24      1            349909   21.0750          NaN        S
# 25      5            347077   31.3875          NaN        S
# 26      0              2631    7.2250          NaN        C
# 27      2             19950  263.0000  C23 C25 C27        S
# 28      0            330959    7.8792          NaN        Q
# 29      0            349216    7.8958          NaN        S
# 30      0          PC 17601   27.7208          NaN        C
# 31      0          PC 17569  146.5208          B78        C
# 32      0            335677    7.7500          NaN        Q
# 33      0        C.A. 24579   10.5000          NaN        S
# 34      0          PC 17604   82.1708          NaN        C
# 35      0            113789   52.0000          NaN        S
# 36      0              2677    7.2292          NaN        C
# 37      0        A./5. 2152    8.0500          NaN        S
# 38      0            345764   18.0000          NaN        S
# 39      0              2651   11.2417          NaN        C
# 40      0              7546    9.4750          NaN        S
# 41      0             11668   21.0000          NaN        S
# 42      0            349253    7.8958          NaN        C
# 43      2     SC/Paris 2123   41.5792          NaN        C
# 44      0            330958    7.8792          NaN        Q
# 45      0   S.C./A.4. 23567    8.0500          NaN        S
# 46      0            370371   15.5000          NaN        Q
# 47      0             14311    7.7500          NaN        Q
# 48      0              2662   21.6792          NaN        C
# 49      0            349237   17.8000          NaN        S
# 50      1           3101295   39.6875          NaN        S
# 51      0        A/4. 39886    7.8000          NaN        S
# 52      0          PC 17572   76.7292          D33        C
# 53      0              2926   26.0000          NaN        S
# 54      1            113509   61.9792          B30        C
# 55      0             19947   35.5000          C52        S
# 56      0        C.A. 31026   10.5000          NaN        S
# 57      0              2697    7.2292          NaN        C
# 58      2        C.A. 34651   27.7500          NaN        S
# 59      2           CA 2144   46.9000          NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(61)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 832          833         0       3                            Saad, Mr. Amin
# 833          834         0       3                    Augustsson, Mr. Albert
# 834          835         0       3                    Allum, Mr. Owen George
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex    Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 830  female  15.00      1      0        2659  14.4542   NaN        C
# 831    male   0.83      1      1       29106  18.7500   NaN        S
# 832    male    NaN      0      0        2671   7.2292   NaN        C
# 833    male  23.00      0      0      347468   7.8542   NaN        S
# 834    male  18.00      0      0        2223   8.3000   NaN        S
# ..      ...    ...    ...    ...         ...      ...   ...      ...
# 886    male  27.00      0      0      211536  13.0000   NaN        S
# 887  female  19.00      0      0      112053  30.0000   B42        S
# 888  female    NaN      1      2  W./C. 6607  23.4500   NaN        S
# 889    male  26.00      0      0      111369  30.0000  C148        C
# 890    male  32.00      0      0      370376   7.7500   NaN        Q
#
# [61 rows x 12 columns]

# %% [markdown]
# # 각 컬럼의 데이터 타입 .dtypes

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # 컬럼명, non이 아닌 데이터 수, 데이터 타입 .info()
# * 컬럼이 너무 많아서 Non-Null Count가 나오지 않을 때 옵션에 show_counts=True를 주면 보임

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 숫자로 된 자료의 기초 통계량을 보고 싶을 때 .describe()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
describe_result = df.describe(include='all')

# %%
describe_result.loc["25%", :]
# Out:
# PassengerId     223.5
# Survived          0.0
# Pclass            2.0
# Name              NaN
# Sex               NaN
# Age            20.125
# SibSp             0.0
# Parch             0.0
# Ticket            NaN
# Fare           7.9104
# Cabin             NaN
# Embarked          NaN
# Name: 25%, dtype: object

# %% [markdown]
# # 데이터 프레임에서 일부 컬럼만 가져오기

# %% [markdown]
# # 1개 컬럼만 가져오는 경우

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %% [markdown]
# # 2개 이상의 컬럼을 가져오는 경우

# %%
df[['Name', 'Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# # 컬럼명 추출하기 .columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Name', 'Age', 'Pclass', 'Survived']]
# Out:
#                                                   Name   Age  Pclass  Survived
# 0                              Braund, Mr. Owen Harris  22.0       3         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1         1
# 2                               Heikkinen, Miss. Laina  26.0       3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1         1
# 4                             Allen, Mr. William Henry  35.0       3         0
# ..                                                 ...   ...     ...       ...
# 886                              Montvila, Rev. Juozas  27.0       2         0
# 887                       Graham, Miss. Margaret Edith  19.0       1         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN       3         0
# 889                              Behr, Mr. Karl Howell  26.0       1         1
# 890                                Dooley, Mr. Patrick  32.0       3         0
#
# [891 rows x 4 columns]

# %% [markdown]
# # loc, iloc를 사용해서 데이터 프레임 잘라오기
# * loc: 데이터프레임의 인덱스명, 컬럼명으로 데이터의 일부를 추출
#   * df.loc[시작row인덱스명 : 끝row인덱스명, 시작column의 컬럼명 : 끝 column의 컬럼명]
# * iloc: 데이터프레임의 인덱스 번호, 컬럼의 인덱스 번호로 데이터의 일부를 추출
#   * df.iloc[시작인덱스번호 : 끝인덱스번호+1 : step, 시작column인덱스번호 : 끝 column 인덱스 번호 +1 : step]

# %%
df.loc[0:10, ['Name', 'Age', 'Pclass', 'Survived']]
# Out:
#                                                  Name   Age  Pclass  Survived
# 0                             Braund, Mr. Owen Harris  22.0       3         0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1         1
# 2                              Heikkinen, Miss. Laina  26.0       3         1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1         1
# 4                            Allen, Mr. William Henry  35.0       3         0
# 5                                    Moran, Mr. James   NaN       3         0
# 6                             McCarthy, Mr. Timothy J  54.0       1         0
# 7                      Palsson, Master. Gosta Leonard   2.0       3         0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0       3         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0       2         1
# 10                    Sandstrom, Miss. Marguerite Rut   4.0       3         1

# %%
df.loc[0:10, 'Survived']
# Out:
# 0     0
# 1     1
# 2     1
# 3     1
# 4     0
# 5     0
# 6     0
# 7     0
# 8     1
# 9     1
# 10    1
# Name: Survived, dtype: int64

# %%
df.loc[890, 'Name']
# Out:
# 'Dooley, Mr. Patrick'

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.iloc[0:11, [3,5,2,1]]
# Out:
#                                                  Name   Age  Pclass  Survived
# 0                             Braund, Mr. Owen Harris  22.0       3         0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1         1
# 2                              Heikkinen, Miss. Laina  26.0       3         1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1         1
# 4                            Allen, Mr. William Henry  35.0       3         0
# 5                                    Moran, Mr. James   NaN       3         0
# 6                             McCarthy, Mr. Timothy J  54.0       1         0
# 7                      Palsson, Master. Gosta Leonard   2.0       3         0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0       3         1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0       2         1
# 10                    Sandstrom, Miss. Marguerite Rut   4.0       3         1

# %%
df.iloc[0:10, 0:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df.iloc[0:10:2, 0:6:2]
# Out:
#    PassengerId  Pclass     Sex
# 0            1       3    male
# 2            3       3  female
# 4            5       3    male
# 6            7       1    male
# 8            9       3  female

# %%
df.iloc[::-1, -3::]
# Out:
#         Fare Cabin Embarked
# 890   7.7500   NaN        Q
# 889  30.0000  C148        C
# 888  23.4500   NaN        S
# 887  30.0000   B42        S
# 886  13.0000   NaN        S
# ..       ...   ...      ...
# 4     8.0500   NaN        S
# 3    53.1000  C123        S
# 2     7.9250   NaN        S
# 1    71.2833   C85        C
# 0     7.2500   NaN        S
#
# [891 rows x 3 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.iloc[890, 3]
# Out:
# 'Dooley, Mr. Patrick'

# %%
df.iloc[890, 3] = '둘리'

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                                        둘리
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# # 컬럼에서 유일값 찾기 unique(), 유일값의 개수 nunique()

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2])

# %%
df['Pclass'].nunique()
# Out:
# 3

# %% [markdown]
# # 유일값의 개수를 셀때 value_counts()

# %%
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts(sort=False)
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64
